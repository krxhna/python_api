# %%
from transformers import pipelines
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e74c4aa8efcb> in <module>
# ----> 1 from transformers import pipelines
#
# ModuleNotFoundError: No module named 'transformers'

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# %%
msft.cashflow
# Out:
#                                              2021-06-30    2020-06-30  \
# Investments                                2.876000e+09  6.980000e+09
# Change To Liabilities                      7.431000e+09  5.230000e+09
# Total Cashflows From Investing Activities -2.757700e+10 -1.222300e+10
# Net Borrowings                            -3.750000e+09 -5.518000e+09
# Total Cash From Financing Activities      -4.848600e+10 -4.603100e+10
# Change To Operating Activities             1.160000e+09 -6.730000e+08
# Issuance Of Stock                          1.693000e+09  1.343000e+09
# Net Income                                 6.127100e+10  4.428100e+10
# Change In Cash                             6.480000e+08  2.220000e+09
# Repurchase Of Stock                       -2.738500e+10 -2.296800e+10
# Effect Of Exchange Rate                   -2.900000e+07 -2.010000e+08
# Total Cash From Operating Activities       7.674000e+10  6.067500e+10
# ...

# %%
df=msft.financials

# %%
df_t=df.transpose()

# %%
df_t.fillna(0)
# Out:
#             Research Development  Effect Of Accounting Charges  \
#
# 2021-06-30          2.071600e+10                             0
# 2020-06-30          1.926900e+10                             0
# 2019-06-30          1.687600e+10                             0
# 2018-06-30          1.472600e+10                             0
#
#             Income Before Tax  Minority Interest    Net Income  \
#
# 2021-06-30       7.110200e+10                  0  6.127100e+10
# 2020-06-30       5.303600e+10                  0  4.428100e+10
# 2019-06-30       4.368800e+10                  0  3.924000e+10
# 2018-06-30       3.647400e+10                  0  1.657100e+10
#
#             Selling General Administrative  Gross Profit          Ebit  \
#
# 2021-06-30                    2.522400e+10  1.158560e+11  6.991600e+10
# 2020-06-30                    2.452300e+10  9.693700e+10  5.314500e+10
# 2019-06-30                    2.309800e+10  8.293300e+10  4.295900e+10
# ...

# %%
	
df_t.fillna(0).rename(columns=str.lower.str.replace(' ','_'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3275b6071189> in <module>
# ----> 1 df_t.fillna(0).rename(columns=str.replace(' ','_'))
#
# TypeError: replace() takes at least 2 arguments (1 given)

# %%
df_t.columns = df_t.columns.str.replace(' ','_')

# %%
df3 = df_t.iloc[0]

# %%
df3
# Out:
# Research_Development                       2.0716e+10
# Effect_Of_Accounting_Charges                     None
# Income_Before_Tax                          7.1102e+10
# Minority_Interest                                None
# Net_Income                                 6.1271e+10
# Selling_General_Administrative             2.5224e+10
# Gross_Profit                              1.15856e+11
# Ebit                                       6.9916e+10
# Operating_Income                           6.9916e+10
# Other_Operating_Expenses                         None
# Interest_Expense                            -2.33e+09
# Extraordinary_Items                              None
# Non_Recurring                                    None
# Other_Items                                      None
# Income_Tax_Expense                          9.831e+09
# Total_Revenue                             1.68088e+11
# Total_Operating_Expenses                   9.8172e+10
# ...

# %%
df3.to_dict()
# Out:
# {'Research_Development': 20716000000.0,
#  'Effect_Of_Accounting_Charges': None,
#  'Income_Before_Tax': 71102000000.0,
#  'Minority_Interest': None,
#  'Net_Income': 61271000000.0,
#  'Selling_General_Administrative': 25224000000.0,
#  'Gross_Profit': 115856000000.0,
#  'Ebit': 69916000000.0,
#  'Operating_Income': 69916000000.0,
#  'Other_Operating_Expenses': None,
#  'Interest_Expense': -2330000000.0,
#  'Extraordinary_Items': None,
#  'Non_Recurring': None,
#  'Other_Items': None,
#  'Income_Tax_Expense': 9831000000.0,
#  'Total_Revenue': 168088000000.0,
#  'Total_Operating_Expenses': 98172000000.0,
#  'Cost_Of_Revenue': 52232000000.0,
#  'Total_Other_Income_Expense_Net': 1186000000.0,
#  'Discontinued_Operations': None,
#  'Net_Income_From_Continuing_Ops': 61271000000.0,
#  'Net_Income_Applicable_To_Common_Shares': 61271000000.0}

# %%
df_t.iloc[0].to_json()
# Out:
# '{"Research Development":20716000000.0,"Effect Of Accounting Charges":null,"Income Before Tax":71102000000.0,"Minority Interest":null,"Net Income":61271000000.0,"Selling General Administrative":25224000000.0,"Gross Profit":115856000000.0,"Ebit":69916000000.0,"Operating Income":69916000000.0,"Other Operating Expenses":null,"Interest Expense":-2330000000.0,"Extraordinary Items":null,"Non Recurring":null,"Other Items":null,"Income Tax Expense":9831000000.0,"Total Revenue":168088000000.0,"Total Operating Expenses":98172000000.0,"Cost Of Revenue":52232000000.0,"Total Other Income Expense Net":1186000000.0,"Discontinued Operations":null,"Net Income From Continuing Ops":61271000000.0,"Net Income Applicable To Common Shares":61271000000.0}'

# %%
null = 0

# %%
data = {"Research Development": 20716000000.0, "Effect Of Accounting Charges": null, "Income Before Tax": 71102000000.0, "Minority Interest": null, "Net Income": 61271000000.0, "Selling General Administrative": 25224000000.0, "Gross Profit": 115856000000.0, "Ebit": 69916000000.0, "Operating Income": 69916000000.0, "Other Operating Expenses": null, "Interest Expense": -2330000000.0,
        "Extraordinary Items": null, "Non Recurring": null, "Other Items": null, "Income Tax Expense": 9831000000.0, "Total Revenue": 168088000000.0, "Total Operating Expenses": 98172000000.0, "Cost Of Revenue": 52232000000.0, "Total Other Income Expense Net": 1186000000.0, "Discontinued Operations": null, "Net Income From Continuing Ops": 61271000000.0, "Net Income Applicable To Common Shares": 61271000000.0}
{"Research Development": 20716000000.0, "Effect Of Accounting Charges": null, "Income Before Tax": 71102000000.0, "Minority Interest": null, "Net Income": 61271000000.0, "Selling General Administrative": 25224000000.0, "Gross Profit": 115856000000.0, "Ebit": 69916000000.0, "Operating Income": 69916000000.0, "Other Operating Expenses": null, "Interest Expense": -2330000000.0, "Extraordinary Items": null,
    "Non Recurring": null, "Other Items": null, "Income Tax Expense": 9831000000.0, "Total Revenue": 168088000000.0, "Total Operating Expenses": 98172000000.0, "Cost Of Revenue": 52232000000.0, "Total Other Income Expense Net": 1186000000.0, "Discontinued Operations": null, "Net Income From Continuing Ops": 61271000000.0, "Net Income Applicable To Common Shares": 61271000000.0}
# Out:
# {'Research Development': 20716000000.0,
#  'Effect Of Accounting Charges': 0,
#  'Income Before Tax': 71102000000.0,
#  'Minority Interest': 0,
#  'Net Income': 61271000000.0,
#  'Selling General Administrative': 25224000000.0,
#  'Gross Profit': 115856000000.0,
#  'Ebit': 69916000000.0,
#  'Operating Income': 69916000000.0,
#  'Other Operating Expenses': 0,
#  'Interest Expense': -2330000000.0,
#  'Extraordinary Items': 0,
#  'Non Recurring': 0,
#  'Other Items': 0,
#  'Income Tax Expense': 9831000000.0,
#  'Total Revenue': 168088000000.0,
#  'Total Operating Expenses': 98172000000.0,
#  'Cost Of Revenue': 52232000000.0,
#  'Total Other Income Expense Net': 1186000000.0,
#  'Discontinued Operations': 0,
#  'Net Income From Continuing Ops': 61271000000.0,
#  'Net Income Applicable To Common Shares': 61271000000.0}

# %%
data['Research Development']
# Out:
# 20716000000.0

# %%
def get_finance(ticker):
    object = yf.Ticker(ticker)
    #gwttng the finance thing
    finance = object.financials
    #transposing
    finance_t = finance
    #picking up the first row 
    res = finance_t.iloc[0].to_json()
    return(res)

# %%
import jsonify

# %%
from bs4 import BeautifulSoup
import requests
import sys

user_agent = {'User-agent': 'Mozilla/5.0'}

# Access page
cik = '200406'
type = '10-K'
dateb = '20210704'

# Obtain HTML for search page
base_url = "https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type={}&dateb={}"
edgar_resp = requests.get(base_url.format(cik, type, dateb),headers=user_agent)
edgar_str = edgar_resp.text

# Find the document link
doc_link = ''
soup = BeautifulSoup(edgar_str, 'html.parser')
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ENG">
# <head>
# <title>EDGAR Search Results</title>
# <link href="/include/interactive.css" rel="stylesheet" type="text/css"/>
# <link href="/edgar/search/css/smartSearchCompanyLanding.css" rel="stylesheet" type="text/css"/>
# <script language="JavaScript" src="/edgar/search/js/smartSearchCompanyLanding.js" type="text/javascript"></script>
# <link href="/cgi-bin/browse-edgar?action=getcompany&amp;CIK=0000200406&amp;type=10-K%25&amp;dateb=20210704&amp;owner=include&amp;count=40&amp;output=atom" rel="alternate" title="ATOM" type="application/atom+xml"/>
# <script>bazadebezolkohpepadr="513202524"</script><script defer="" src="https://www.sec.gov/akam/13/1e96da93" type="text/javascript"></script></head>
# <body style="margin: 0">
# <!-- SEC Web Analytics - For information please visit: https://www.sec.gov/privacy.htm#collectedinfo -->
# ...

# %%
roic=requests.get('https://roic.ai/company/MSFT')

# %%
base_url.format(cik, type, dateb)
# Out:
# 'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=200406&type=10-K&dateb=20210704'

# %%
roic.get

# %%
BeautifulSoup(roic.text)
# Out:
# <!DOCTYPE html>
# ...
